# %% [markdown]
# ##Pandas
# ในการทำงาน machine learning จำเป็นต้องมีการจัดการข้อมูล และเตรียมข้อมูลเบื้องต้น ก่อนนำเข้าอัลกอริทึม machine learning
# Pandas เป็นเครื่องมือที่มีประสิทธิภาพที่มีความสามารถในการจัดการและเตรียมข้อมูลเบื้องต้นได้อย่างมีประสิทธิภาพตั้งแต่ข้อมูลขนาดเล็กไปจนถึงขนาดใหญ่

# %%
import pandas as pd                ## import pandas lib.

# %% [markdown]
# # Iris Dataset
# ![](https://miro.medium.com/v2/resize:fit:720/format:webp/1*7bnLKsChXq94QjtAiRn40w.png)
#
# The features (attributes) of the dataset:
# * Id
# * SepalLengthCm
# * SepalWidthCm
# * PetalLengthCm
# * PetalWidthCm
#
# The labels of the dataset:
# * Species
# * Label: 0 (Setosa) 1 (Versicolor) and 2 (Virginica)

# %% [markdown]
# ## Read the dataset from csv file

# %%
# Out:
#       id  label  sepal.length  sepal.width  petal.length  petal.width
# 0      1      0           5.1          3.5           1.4          0.2
# 1      2      0           4.9          3.0           NaN          0.2
# 2      3      0           4.7          3.2           1.3          0.2
# 3      4      0           4.6          3.1           1.5          0.2
# 4      5      0           5.0          3.6           1.4          0.2
# ..   ...    ...           ...          ...           ...          ...
# 145  146      2           6.7          3.0           5.2          2.3
# 146  147      2           6.3          2.5           5.0          1.9
# 147  148      2           6.5          NaN           5.2          2.0
# 148  149      2           6.2          3.4           5.4          2.3
# 149  150      2           5.9          3.0           5.1          NaN
#
# [150 rows x 6 columns]

# %% [markdown]
# **DataFrame** is a 2-dimensional data structure with the columns of potentially differences like a spreadsheet or SQL table.

# %%
type(df)                                        ## show type of variable
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()                        ## view only the first 5 rows in dataframe
# Out:
#    id  label  sepal.length  sepal.width  petal.length  petal.width
# 0   1      0           5.1          3.5           1.4          0.2
# 1   2      0           4.9          3.0           NaN          0.2
# 2   3      0           4.7          3.2           1.3          0.2
# 3   4      0           4.6          3.1           1.5          0.2
# 4   5      0           5.0          3.6           1.4          0.2

# %%
df.tail(3)                          ## view only the last 3 rows in dataframe
# Out:
#       id  label  sepal.length  sepal.width  petal.length  petal.width
# 147  148      2           6.5          NaN           5.2          2.0
# 148  149      2           6.2          3.4           5.4          2.3
# 149  150      2           5.9          3.0           5.1          NaN

# %%
df.columns                      ## get columns
# Out:
# Index(['id', 'label', 'sepal.length', 'sepal.width', 'petal.length',
#        'petal.width'],
#       dtype='object')

# %%
                              ## get column types
# Out:
# id                int64
# label             int64
# sepal.length    float64
# sepal.width     float64
# petal.length    float64
# petal.width     float64
# dtype: object

# %%
                              ## show data statistics
# Out:
#                id       label  sepal.length  sepal.width  petal.length  \
# count  150.000000  150.000000    145.000000   145.000000    143.000000
# mean    75.500000    1.000000      5.848966     3.054483      3.804196
# std     43.445368    0.819232      0.827825     0.437000      1.751936
# min      1.000000    0.000000      4.300000     2.000000      1.100000
# 25%     38.250000    0.000000      5.100000     2.800000      1.600000
# 50%     75.500000    1.000000      5.800000     3.000000      4.400000
# 75%    112.750000    2.000000      6.400000     3.300000      5.100000
# max    150.000000    2.000000      7.900000     4.400000      6.900000
#
#        petal.width
# count   144.000000
# mean      1.202083
# std       0.757570
# min       0.100000
# 25%       0.300000
# 50%       1.300000
# 75%       1.800000
# max       2.500000

# %%
                                ## sort values in descending order for 'sepal.length'
# Out:
#       id  label  sepal.length  sepal.width  petal.length  petal.width
# 32    33      0           5.2          4.1           1.5          0.1
# 13    14      0           4.3          3.0           1.1          0.1
# 37    38      0           4.9          3.6           1.4          0.1
# 12    13      0           4.8          3.0           1.4          0.1
# 9     10      0           4.9          3.1           1.5          0.1
# ..   ...    ...           ...          ...           ...          ...
# 43    44      0           5.0          3.5           1.6          NaN
# 47    48      0           4.6          3.2           1.4          NaN
# 84    85      1           5.4          3.0           4.5          NaN
# 109  110      2           7.2          3.6           6.1          NaN
# 149  150      2           5.9          3.0           5.1          NaN
#
# [150 rows x 6 columns]

# %%
X = df['sepal.length']                        ## select 'sepal.length' feature
X
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal.length, Length: 150, dtype: float64

# %%
                  ## select 'sepal.length' and 'sepal.width' features
# Out:
#      sepal.length  sepal.width
# 0             5.1          3.5
# 1             4.9          3.0
# 2             4.7          3.2
# 3             4.6          3.1
# 4             5.0          3.6
# ..            ...          ...
# 145           6.7          3.0
# 146           6.3          2.5
# 147           6.5          NaN
# 148           6.2          3.4
# 149           5.9          3.0
#
# [150 rows x 2 columns]

# %%
YY = df.loc[df['sepal.length'] > 5.0]                   ## select rows with sepal.length > 5.0
YY
# Out:
#       id  label  sepal.length  sepal.width  petal.length  petal.width
# 0      1      0           5.1          3.5           1.4          0.2
# 10    11      0           5.4          3.7           1.5          0.2
# 14    15      0           5.8          4.0           1.2          0.2
# 15    16      0           5.7          4.4           1.5          0.4
# 16    17      0           5.4          3.9           1.3          0.4
# ..   ...    ...           ...          ...           ...          ...
# 145  146      2           6.7          3.0           5.2          2.3
# 146  147      2           6.3          2.5           5.0          1.9
# 147  148      2           6.5          NaN           5.2          2.0
# 148  149      2           6.2          3.4           5.4          2.3
# 149  150      2           5.9          3.0           5.1          NaN
#
# [115 rows x 6 columns]

# %%
YY = df.loc[ (df['label'] == 0) & (df['petal.width'] >= 0.2) ]       ## select rows of Iris 'Setasa' with petal.width >= 0.2
YY
# Out:
#     id  label  sepal.length  sepal.width  petal.length  petal.width
# 0    1      0           5.1          3.5           1.4          0.2
# 1    2      0           4.9          3.0           NaN          0.2
# 2    3      0           4.7          3.2           1.3          0.2
# 3    4      0           4.6          3.1           1.5          0.2
# 4    5      0           5.0          3.6           1.4          0.2
# 5    6      0           NaN          3.9           1.7          0.4
# 6    7      0           4.6          3.4           1.4          0.3
# 7    8      0           5.0          3.4           1.5          0.2
# 8    9      0           4.4          2.9           1.4          0.2
# 10  11      0           5.4          3.7           1.5          0.2
# 11  12      0           4.8          3.4           NaN          0.2
# 14  15      0           5.8          4.0           1.2          0.2
# 15  16      0           5.7          4.4           1.5          0.4
# ...

# %% [markdown]
# ## Data Pre-processing process

# %% [markdown]
# ## Drop irrelevant columns

# %%
df = df.drop()                                      ## remove the column 'id' from the dataset
df
# Out:
#      label  sepal.length  sepal.width  petal.length  petal.width
# 0        0           5.1          3.5           1.4          0.2
# 1        0           4.9          3.0           NaN          0.2
# 2        0           4.7          3.2           1.3          0.2
# 3        0           4.6          3.1           1.5          0.2
# 4        0           5.0          3.6           1.4          0.2
# ..     ...           ...          ...           ...          ...
# 145      2           6.7          3.0           5.2          2.3
# 146      2           6.3          2.5           5.0          1.9
# 147      2           6.5          NaN           5.2          2.0
# 148      2           6.2          3.4           5.4          2.3
# 149      2           5.9          3.0           5.1          NaN
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Check missing values

# %%
df.isna().sum()                                ## check 'NaN' (Not a Number) values from all the attributes
# Out:
# label           0
# sepal.length    5
# sepal.width     5
# petal.length    7
# petal.width     6
# dtype: int64

# %%
                                               ## drop rows with existing missing values
df2
# Out:
#      label  sepal.length  sepal.width  petal.length  petal.width
# 0        0           5.1          3.5           1.4          0.2
# 2        0           4.7          3.2           1.3          0.2
# 3        0           4.6          3.1           1.5          0.2
# 4        0           5.0          3.6           1.4          0.2
# 6        0           4.6          3.4           1.4          0.3
# ..     ...           ...          ...           ...          ...
# 142      2           5.8          2.7           5.1          1.9
# 143      2           6.8          3.2           5.9          2.3
# 145      2           6.7          3.0           5.2          2.3
# 146      2           6.3          2.5           5.0          1.9
# 148      2           6.2          3.4           5.4          2.3
#
# [128 rows x 5 columns]

# %%
df = df.fillna(df.mean())                        ## replace all missing values by average
df
# Out:
#      label  sepal.length  sepal.width  petal.length  petal.width
# 0        0           5.1     3.500000      1.400000     0.200000
# 1        0           4.9     3.000000      3.804196     0.200000
# 2        0           4.7     3.200000      1.300000     0.200000
# 3        0           4.6     3.100000      1.500000     0.200000
# 4        0           5.0     3.600000      1.400000     0.200000
# ..     ...           ...          ...           ...          ...
# 145      2           6.7     3.000000      5.200000     2.300000
# 146      2           6.3     2.500000      5.000000     1.900000
# 147      2           6.5     3.054483      5.200000     2.000000
# 148      2           6.2     3.400000      5.400000     2.300000
# 149      2           5.9     3.000000      5.100000     1.202083
#
# [150 rows x 5 columns]

# %%
from sklearn.preprocessing import MinMaxScaler                    ## feature scaling using min-max normalization

scaler = MinMaxScaler(feature_range=(-1, 1))                      ## set the range of features in between -1 and +1

df['sepal.length'] = scaler.fit_transform(df[['sepal.length']])   ##  transform the original features 'sepal.length'
df
# Out:
#      label  sepal.length  sepal.width  petal.length  petal.width
# 0        0     -0.555556     3.500000      1.400000     0.200000
# 1        0     -0.666667     3.000000      3.804196     0.200000
# 2        0     -0.777778     3.200000      1.300000     0.200000
# 3        0     -0.833333     3.100000      1.500000     0.200000
# 4        0     -0.611111     3.600000      1.400000     0.200000
# ..     ...           ...          ...           ...          ...
# 145      2      0.333333     3.000000      5.200000     2.300000
# 146      2      0.111111     2.500000      5.000000     1.900000
# 147      2      0.222222     3.054483      5.200000     2.000000
# 148      2      0.055556     3.400000      5.400000     2.300000
# 149      2     -0.111111     3.000000      5.100000     1.202083
#
# [150 rows x 5 columns]

# %%
from sklearn.preprocessing import StandardScaler                   ## feature scaling using Z-score normalization

scaler = StandardScaler()
                                                                   ##  transform the original features 'petal.width'
df
# Out:
#      label  sepal.length  sepal.width  petal.length  petal.width
# 0        0     -0.555556     3.500000      1.400000    -1.354749
# 1        0     -0.666667     3.000000      3.804196    -1.354749
# 2        0     -0.777778     3.200000      1.300000    -1.354749
# 3        0     -0.833333     3.100000      1.500000    -1.354749
# 4        0     -0.611111     3.600000      1.400000    -1.354749
# ..     ...           ...          ...           ...          ...
# 145      2      0.333333     3.000000      5.200000     1.484309
# 146      2      0.111111     2.500000      5.000000     0.943536
# 147      2      0.222222     3.054483      5.200000     1.078730
# 148      2      0.055556     3.400000      5.400000     1.484309
# 149      2     -0.111111     3.000000      5.100000     0.000000
#
# [150 rows x 5 columns]

# %%
cor = df.corr()                                                           ## generate correlation matrix
cor
# Out:
#                  label  sepal.length  sepal.width  petal.length  petal.width
# label         1.000000      0.763065    -0.412938      0.918207     0.932729
# sepal.length  0.763065      1.000000    -0.109595      0.823899     0.770644
# sepal.width  -0.412938     -0.109595     1.000000     -0.413214    -0.359065
# petal.length  0.918207      0.823899    -0.413214      1.000000     0.899415
# petal.width   0.932729      0.770644    -0.359065      0.899415     1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))                ## set size of heatmap

sns.heatmap(cor, annot = True)
plt.title('HEAT MAP')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fa76ff1f713c> in <cell line: 5>()
#       3
#       4 plt.figure(figsize=(8, 6))                ## set size of heatmap
# ----> 5 cor = df.corr()                          ## compute correlation matrix with Pearson correlation
#       6 sns.heatmap(cor, annot = True)
#       7 plt.title('HEAT MAP')
#
# NameError: name 'df' is not defined

# %%
cor_target = cor['label']                              ## select column 'label' in correlation matrix

relevant_features = cor_target[cor_target > 0.8]       ## select the most relevant features with threshold > 0.8
relevant_features
# Out:
# label           1.000000
# petal.length    0.918207
# petal.width     0.932729
# Name: label, dtype: float64

# %% [markdown]
# ## LAB Sheet
#
# # Pima Indians Diabetes dataset
# ![](https://ankhoudary12.github.io/assets/diabetes_images/pima.jpeg)
#
# The features (attributes) of the dataset:
# *   Pregnancies (preg) : number of times pregnant
# * Glucose (Plas): concentration of glucose in blood 2 hrs after ingestion of sugary drink (mmol/L)
# *   Blood Pressure (pres): diastolic blood pressure (mm Hg)
# *   Skin Thickness (skin): triceps skin fold thickness (mm)
# *   Insulin (insu): concentration of insulin in blood 2 hrs after ingestion of sugary drink (μU/mL)
# *   BMI (mass): body mass index (weight in kg/(height in m)^2)
# *   Diabetes Pedigree Function (Predi): 0:1 value generated from familial diabetes history/risk
# *   Age: age of patient
#
# The output of the dataset:
# * Label: 'tested_negative'  and 'tested_positive'

# %% [markdown]
# ## อ่านและแสดงข้อมูลจากไฟล์ pima_diabets.csv

# %%
import pandas as pd                                  ## import pandas library


df
# Out:
#      Unnamed: 0  preg   plas  pres  skin   insu  mass   pedi  age  \
# 0             0   6.0  148.0  72.0  35.0    NaN  33.6  0.627   50
# 1             1   1.0   85.0  66.0  29.0    NaN  26.6  0.351   31
# 2             2   8.0  183.0  64.0   NaN    NaN  23.3  0.672   32
# 3             3   1.0   89.0  66.0  23.0   94.0  28.1  0.167   21
# 4             4   NaN  137.0  40.0  35.0  168.0  43.1  2.288   33
# ..          ...   ...    ...   ...   ...    ...   ...    ...  ...
# 763         763  10.0  101.0  76.0  48.0  180.0  32.9  0.171   63
# 764         764   2.0  122.0  70.0  27.0    NaN  36.8  0.340   27
# 765         765   5.0  121.0  72.0  23.0  112.0  26.2  0.245   30
# 766         766   1.0  126.0  60.0   NaN    NaN  30.1  0.349   47
# 767         767   1.0   93.0  70.0  31.0    NaN  30.4  0.315   23
#
#                class
# 0    tested_positive
# 1    tested_negative
# 2    tested_positive
# 3    tested_negative
# 4    tested_positive
# ..               ...
# ...

# %% [markdown]
# แสดงข้อมูลผู้ป่วยที่มีอายุมากกว่า 30 และมีความหนาของผิวหนัง (skin) มากกว่า 35 มิิลลิเมตรขึ้นไป

# %%
YY
# Out:
#      Unnamed: 0  preg   plas  pres  skin   insu  mass   pedi  age  \
# 8             8   2.0  197.0  70.0  45.0  543.0  30.5  0.158   53
# 16           16   NaN  118.0  84.0  47.0  230.0  45.8  0.551   31
# 18           18   1.0  103.0  30.0  38.0   83.0  43.3  0.183   33
# 37           37   9.0  102.0  76.0  37.0    NaN  32.9  0.665   46
# 39           39   4.0  111.0  72.0  47.0  207.0  37.1  1.390   56
# ..          ...   ...    ...   ...   ...    ...   ...    ...  ...
# 744         744  13.0  153.0  88.0  37.0  140.0  40.6  1.174   39
# 747         747   1.0   81.0  74.0  41.0   57.0  46.3  1.096   32
# 755         755   1.0  128.0  88.0  39.0  110.0  36.5  1.057   37
# 756         756   7.0  137.0  90.0  41.0    NaN  32.0  0.391   39
# 763         763  10.0  101.0  76.0  48.0  180.0  32.9  0.171   63
#
#                class
# 8    tested_positive
# 16   tested_positive
# 18   tested_negative
# 37   tested_positive
# 39   tested_positive
# ..               ...
# ...

# %% [markdown]
# ลบคอลัมน์ Unnamed: 0 ออกจาก dataframe พร้อมแสดงผลลัพธ์

# %%
df
# Out:
#      preg   plas  pres  skin   insu  mass   pedi  age            class
# 0     6.0  148.0  72.0  35.0    NaN  33.6  0.627   50  tested_positive
# 1     1.0   85.0  66.0  29.0    NaN  26.6  0.351   31  tested_negative
# 2     8.0  183.0  64.0   NaN    NaN  23.3  0.672   32  tested_positive
# 3     1.0   89.0  66.0  23.0   94.0  28.1  0.167   21  tested_negative
# 4     NaN  137.0  40.0  35.0  168.0  43.1  2.288   33  tested_positive
# ..    ...    ...   ...   ...    ...   ...    ...  ...              ...
# 763  10.0  101.0  76.0  48.0  180.0  32.9  0.171   63  tested_negative
# 764   2.0  122.0  70.0  27.0    NaN  36.8  0.340   27  tested_negative
# 765   5.0  121.0  72.0  23.0  112.0  26.2  0.245   30  tested_negative
# 766   1.0  126.0  60.0   NaN    NaN  30.1  0.349   47  tested_positive
# 767   1.0   93.0  70.0  31.0    NaN  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %% [markdown]
# กำจัด missing values โดยวิธี replace by means

# %%
# Out:
#           preg   plas  pres      skin        insu  mass   pedi  age  class
# 0     6.000000  148.0  72.0  35.00000  155.548223  33.6  0.627   50      1
# 1     1.000000   85.0  66.0  29.00000  155.548223  26.6  0.351   31      0
# 2     8.000000  183.0  64.0  29.15342  155.548223  23.3  0.672   32      1
# 3     1.000000   89.0  66.0  23.00000   94.000000  28.1  0.167   21      0
# 4     4.494673  137.0  40.0  35.00000  168.000000  43.1  2.288   33      1
# ..         ...    ...   ...       ...         ...   ...    ...  ...    ...
# 763  10.000000  101.0  76.0  48.00000  180.000000  32.9  0.171   63      0
# 764   2.000000  122.0  70.0  27.00000  155.548223  36.8  0.340   27      0
# 765   5.000000  121.0  72.0  23.00000  112.000000  26.2  0.245   30      0
# 766   1.000000  126.0  60.0  29.15342  155.548223  30.1  0.349   47      1
# 767   1.000000   93.0  70.0  31.00000  155.548223  30.4  0.315   23      0
#
# [768 rows x 9 columns]

# %% [markdown]
# ปรับค่า feature 'plas' และ 'skin' ให้อยู่ระหว่าง 0 ถึง 1

# %%
# Out:
#           preg      plas  pres      skin        insu  mass   pedi  age  class
# 0     6.000000  0.670968  72.0  0.304348  155.548223  33.6  0.627   50      1
# 1     1.000000  0.264516  66.0  0.239130  155.548223  26.6  0.351   31      0
# 2     8.000000  0.896774  64.0  0.240798  155.548223  23.3  0.672   32      1
# 3     1.000000  0.290323  66.0  0.173913   94.000000  28.1  0.167   21      0
# 4     4.494673  0.600000  40.0  0.304348  168.000000  43.1  2.288   33      1
# ..         ...       ...   ...       ...         ...   ...    ...  ...    ...
# 763  10.000000  0.367742  76.0  0.445652  180.000000  32.9  0.171   63      0
# 764   2.000000  0.503226  70.0  0.217391  155.548223  36.8  0.340   27      0
# 765   5.000000  0.496774  72.0  0.173913  112.000000  26.2  0.245   30      0
# 766   1.000000  0.529032  60.0  0.240798  155.548223  30.1  0.349   47      1
# 767   1.000000  0.316129  70.0  0.260870  155.548223  30.4  0.315   23      0
#
# [768 rows x 9 columns]

# %% [markdown]
# ปรับค่า feature 'insu' ให้อยู่ในรูปของค่าคะแนน Z

# %%
# Out:
#           preg      plas  pres      skin          insu  mass   pedi  age  \
# 0     6.000000  0.670968  72.0  0.304348 -3.345079e-16  33.6  0.627   50
# 1     1.000000  0.264516  66.0  0.239130 -3.345079e-16  26.6  0.351   31
# 2     8.000000  0.896774  64.0  0.240798 -3.345079e-16  23.3  0.672   32
# 3     1.000000  0.290323  66.0  0.173913 -7.243887e-01  28.1  0.167   21
# 4     4.494673  0.600000  40.0  0.304348  1.465506e-01  43.1  2.288   33
# ..         ...       ...   ...       ...           ...   ...    ...  ...
# 763  10.000000  0.367742  76.0  0.445652  2.877840e-01  32.9  0.171   63
# 764   2.000000  0.503226  70.0  0.217391 -3.345079e-16  36.8  0.340   27
# 765   5.000000  0.496774  72.0  0.173913 -5.125386e-01  26.2  0.245   30
# 766   1.000000  0.529032  60.0  0.240798 -3.345079e-16  30.1  0.349   47
# 767   1.000000  0.316129  70.0  0.260870 -3.345079e-16  30.4  0.315   23
#
#      class
# 0        1
# 1        0
# 2        1
# 3        0
# 4        1
# ..     ...
# ...

# %% [markdown]
# แสดงค่า correlation matrix ของชุดข้อมูล

# %% [markdown]
# แสดงค่า correlation ที่มากที่สุด เรียงจากมากไปน้อย ของ 3 features ที่สัมพันธ์กับ 'class'

# %%
# Out:
# plas    0.492928
# mass    0.311924
# preg    0.248263
# Name: class, dtype: float64

# %% [markdown]
# เลือก 3 columns และ class จาก dataframe พร้อมบันทึกไฟล์ข้อมูลใหม่ในรูปของไฟล์ csv ตั้งชื่อ  new_data.csv

# %%
df2.to_csv('new_data.csv')
